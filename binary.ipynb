# %%
# !pip install tensorflow
# !pip install keras
# !pip install --upgrade tensorflow keras h5py keras-preprocessing decorator
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /home/fatguy/.local/lib/python3.11/site-packages (2.19.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: keras>=3.5.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: libclang>=13.0.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: h5py>=3.11.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (59.6.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: packaging in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: rich in /home/fatguy/.local/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /home/fatguy/.local/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /home/fatguy/.local/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/fatguy/.local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow) (2020.6.20)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.3.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/fatguy/.local/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/fatguy/.local/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/fatguy/.local/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/fatguy/.local/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in /home/fatguy/.local/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: ml-dtypes in /home/fatguy/.local/lib/python3.11/site-packages (from keras) (0.5.1)
# Requirement already satisfied: rich in /home/fatguy/.local/lib/python3.11/site-packages (from keras) (14.0.0)
# Requirement already satisfied: namex in /home/fatguy/.local/lib/python3.11/site-packages (from keras) (0.0.9)
# Requirement already satisfied: numpy in /home/fatguy/.local/lib/python3.11/site-packages (from keras) (1.26.4)
# Requirement already satisfied: packaging in /home/fatguy/.local/lib/python3.11/site-packages (from keras) (25.0)
# Requirement already satisfied: absl-py in /home/fatguy/.local/lib/python3.11/site-packages (from keras) (2.2.2)
# Requirement already satisfied: h5py in /home/fatguy/.local/lib/python3.11/site-packages (from keras) (3.13.0)
# Requirement already satisfied: optree in /home/fatguy/.local/lib/python3.11/site-packages (from keras) (0.15.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/fatguy/.local/lib/python3.11/site-packages (from optree->keras) (4.13.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/fatguy/.local/lib/python3.11/site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/fatguy/.local/lib/python3.11/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/fatguy/.local/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /home/fatguy/.local/lib/python3.11/site-packages (2.19.0)
# Requirement already satisfied: keras in /home/fatguy/.local/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: h5py in /home/fatguy/.local/lib/python3.11/site-packages (3.13.0)
# Requirement already satisfied: keras-preprocessing in /home/fatguy/.local/lib/python3.11/site-packages (1.1.2)
# Requirement already satisfied: decorator in /home/fatguy/.local/lib/python3.11/site-packages (5.2.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: packaging in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (59.6.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: optree in /home/fatguy/.local/lib/python3.11/site-packages (from keras) (0.15.0)
# Requirement already satisfied: namex in /home/fatguy/.local/lib/python3.11/site-packages (from keras) (0.0.9)
# Requirement already satisfied: rich in /home/fatguy/.local/lib/python3.11/site-packages (from keras) (14.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/fatguy/.local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow) (2020.6.20)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow) (1.26.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.3.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/fatguy/.local/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/fatguy/.local/lib/python3.11/site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/fatguy/.local/lib/python3.11/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/fatguy/.local/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/fatguy/.local/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

vocab_size = 10000
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)

# Pad sequences
maxlen = 256
X_train = pad_sequences(X_train, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)

# Build model
model = keras.Sequential([
    layers.Embedding(input_dim=vocab_size, output_dim=32, input_length=maxlen),
    layers.GlobalAveragePooling1D(),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# Compile
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow import keras
#       3 from tensorflow.keras import layers
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/__init__.py:49
#      46 from tensorflow.python import tf2 as _tf2
#      47 _tf2.enable()
# ---> 49 from tensorflow._api.v2 import __internal__
#      50 from tensorflow._api.v2 import __operators__
#      51 from tensorflow._api.v2 import audio
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/_api/v2/__internal__/__init__.py:8
#       3 """Public API for tf._api.v2.__internal__ namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__ import autograph
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/_api/v2/__internal__/autograph/__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.autograph namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#       9 from tensorflow.python.autograph.impl.api import tf_convert # line: 493
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/python/autograph/core/ag_ctx.py:21
#      18 import inspect
#      19 import threading
# ---> 21 from tensorflow.python.autograph.utils import ag_logging
#      22 from tensorflow.python.util.tf_export import tf_export
#      25 stacks = threading.local()
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/python/autograph/utils/__init__.py:17
#       1 # Copyright 2016 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Utility module that contains APIs usable in the generated code."""
# ---> 17 from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#      18 from tensorflow.python.autograph.utils.misc import alias_tensors
#      19 from tensorflow.python.autograph.utils.tensor_list import dynamic_list_append
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/python/autograph/utils/context_managers.py:19
#      15 """Various context managers."""
#      17 import contextlib
# ---> 19 from tensorflow.python.framework import ops
#      20 from tensorflow.python.ops import tensor_array_ops
#      23 def control_dependency_on_returns(return_value):
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:50
#      48 from tensorflow.python import tf2
#      49 from tensorflow.python.client import pywrap_tf_session
# ---> 50 from tensorflow.python.eager import context
#      51 from tensorflow.python.eager import core
#      52 from tensorflow.python.eager import monitoring
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/python/eager/context.py:38
#      36 from tensorflow.python.client import pywrap_tf_session
#      37 from tensorflow.python.eager import cancellation
# ---> 38 from tensorflow.python.eager import execute
#      39 from tensorflow.python.eager import executor
#      40 from tensorflow.python.eager import monitoring
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:23
#      21 from tensorflow.python.framework import dtypes
#      22 from tensorflow.python.framework import tensor_conversion_registry
# ---> 23 from tensorflow.python.framework import tensor_shape
#      24 from tensorflow.python.types import core as core_types
#      25 from tensorflow.python.util import compat
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/python/framework/tensor_shape.py:26
#      24 from tensorflow.python.eager import monitoring
#      25 from tensorflow.python.platform import tf_logging as logging
# ---> 26 from tensorflow.python.saved_model import nested_structure_coder
#      27 from tensorflow.python.types import trace
#      28 from tensorflow.python.util.tf_export import tf_export
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/python/saved_model/nested_structure_coder.py:38
#      36 from tensorflow.python.types import internal
#      37 from tensorflow.python.util import compat
# ---> 38 from tensorflow.python.util import nest
#      39 from tensorflow.python.util.compat import collections_abc
#      40 from tensorflow.python.util.tf_export import tf_export
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/python/util/nest.py:95
#      93 from tensorflow.python.util import _pywrap_nest
#      94 from tensorflow.python.util import _pywrap_utils
# ---> 95 from tensorflow.python.util import nest_util
#      96 from tensorflow.python.util.tf_export import tf_export
#      99 STRUCTURES_HAVE_MISMATCHING_LENGTHS = (
#     100     nest_util.STRUCTURES_HAVE_MISMATCHING_LENGTHS
#     101 )
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:30
#      27 import collections as _collections
#      28 import enum
# ---> 30 import wrapt as _wrapt
#      32 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      33 from tensorflow.python.platform import tf_logging
#
# File /usr/lib/python3/dist-packages/wrapt/__init__.py:10
#       2 __version__ = '.'.join(__version_info__)
#       4 from .wrappers import (ObjectProxy, CallableObjectProxy, FunctionWrapper,
#       5         BoundFunctionWrapper, WeakFunctionProxy, PartialCallableObjectProxy,
#       6         resolve_path, apply_patch, wrap_object, wrap_object_attribute,
#       7         function_wrapper, wrap_function_wrapper, patch_function_wrapper,
#       8         transient_function_wrapper)
# ---> 10 from .decorators import (adapter_factory, AdapterFactory, decorator,
#      11         synchronized)
#      13 from .importer import (register_post_import_hook, when_imported,
#      14         notify_module_loaded, discover_post_import_hooks)
#      16 from inspect import getcallargs
#
# File /usr/lib/python3/dist-packages/wrapt/decorators.py:34
#      31     del builtins
#      33 from functools import partial
# ---> 34 from inspect import ismethod, isclass, formatargspec
#      35 from collections import namedtuple
#      36 from threading import Lock, RLock
#
# ImportError: cannot import name 'formatargspec' from 'inspect' (/usr/lib/python3.11/inspect.py)
